# %%
# !nvidia-smi
# Out:
# Wed May 22 03:21:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
# !git clone https://github.com/odegeasslbc/FastGAN-pytorch.git
# Out:
# Cloning into 'FastGAN-pytorch'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 192 (delta 44), reused 56 (delta 36), pack-reused 108
# Receiving objects: 100% (192/192), 151.65 KiB | 15.16 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !pip3 install torch==2.0.0+cu118 torchvision==0.15.0+cu118 torchaudio==2.0.0+cu118 --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install lmdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 513.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
# ...

# %%
# %cd /content/FastGAN-pytorch
# !python3 train.py --path /content/drive/MyDrive/data/datasets --out /content/drive/MyDrive/data/experiments --cuda 0 --iter 10000 --im_size 256 --batch_size 8 --save_interval 100 --name new_atopic
# Out:
# /content/FastGAN-pytorch
# Setting up Perceptual loss...
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:07<00:00, 78.8MB/s]
# Loading model from: /content/FastGAN-pytorch/lpips/weights/v0.1/vgg.pth
# ...[net-lin [vgg]] initialized
# ...Done
# Namespace(path='/content/drive/MyDrive/data/datasets', output_path='/content/drive/MyDrive/data/experiments', cuda=0, name='new_atopic', iter=10000, start_iter=0, batch_size=8, im_size=256, ckpt='None', workers=2, save_interval=100)
#   0% 0/10001 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# GAN: loss d: 0.08605    loss g: -0.67685
# ...

# %%
# %cd /content/drive/MyDrive/data/experiments/train_results/new_atopic
# !python3 eval.py --n_sample 1000 --im_size 256 --start_iter 1 --end_iter 1
# Out:
# /content/drive/MyDrive/data/experiments/train_results/new_atopic
# load checkpoint success, epoch 10000
# 100% 62/62 [00:44<00:00,  1.38it/s]

# %%
# %cd /content/FastGAN-pytorch
# !python3 train.py --path /content/drive/MyDrive/data/images/bicubic_atopic_256 --out /content/drive/MyDrive/data/experiments --cuda 1 --iter 2400 --start_iter 1200 --im_size 256 --save_interval 50 --batch_size 8 --name atopic
# Out:
# /content/FastGAN-pytorch
# Setting up Perceptual loss...
# Loading model from: /content/FastGAN-pytorch/lpips/weights/v0.1/vgg.pth
# ...[net-lin [vgg]] initialized
# ...Done
# Namespace(path='/content/drive/MyDrive/data/images/bicubic_atopic_256', output_path='/content/drive/MyDrive/data/experiments', cuda=1, name='atopic', iter=2400, start_iter=1200, batch_size=8, im_size=256, ckpt='None', workers=2, save_interval=50)
#   0% 0/1201 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# GAN: loss d: 0.06708    loss g: -0.28531
#   8% 100/1201 [00:57<10:42,  1.71it/s]GAN: loss d: -0.15603    loss g: -0.34013
#  17% 200/1201 [01:58<10:15,  1.63it/s]GAN: loss d: -0.07328    loss g: -0.40118
# ...

# %%
# %cd /content/FastGAN-pytorch
# !python3 diffaug.py --help
# Out:
# /content/FastGAN-pytorch
